# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import KFold
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import LabelBinarizer

from sklearn import svm
from sklearn import datasets

# %load_ext autoreload
# %autoreload 2
pd.__version__
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# '0.23.4'

# %%
from wrldrmt import Utility

# %%
i0 = Utility.instance()
i0.lbl2n(None)

df0 = pd.read_csv('data.csv')

# %%
df0.info()
t0 = df0.columns.to_series().groupby(df0.dtypes).groups
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299285 entries, 0 to 299284
# Data columns (total 41 columns):
# age                                           299285 non-null int64
# class_of_worker                               299285 non-null object
# detailed_industry_recode                      299285 non-null int64
# detailed_occupation_recode                    299285 non-null int64
# education                                     299285 non-null object
# wage_per_hour                                 299285 non-null int64
# enroll_in_edu_inst_last_wk                    299285 non-null object
# marital_stat                                  299285 non-null object
# major_industry_code                           299285 non-null object
# major_occupation_code                         299285 non-null object
# race                                          299285 non-null object
# hispanic_origin                               298006 non-null object
# ...

# %%
t1=t0.keys()
t2=list(t1)
t2[1]
# Out:
# dtype('O')

# %%
np.dtype('O')
# Out:
# dtype('O')

# %%
t3 = i0.dtypes(df0)

# %%
df1 = i0.str2cat(df0)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299285 entries, 0 to 299284
# Data columns (total 41 columns):
# age                                           299285 non-null int64
# class_of_worker                               299285 non-null category
# detailed_industry_recode                      299285 non-null int64
# detailed_occupation_recode                    299285 non-null int64
# education                                     299285 non-null category
# wage_per_hour                                 299285 non-null int64
# enroll_in_edu_inst_last_wk                    299285 non-null category
# marital_stat                                  299285 non-null category
# major_industry_code                           299285 non-null category
# major_occupation_code                         299285 non-null category
# race                                          299285 non-null category
# hispanic_origin                               298006 non-null category
# ...

# %%
dict([ (x, tuple(df1[x].cat.categories)) for x in df1.select_dtypes(['category']).columns ])
# Out:
# {'class_of_worker': ('Federal government',
#   'Local government',
#   'Never worked',
#   'Not in universe',
#   'Private',
#   'Self-employed-incorporated',
#   'Self-employed-not incorporated',
#   'State government',
#   'Without pay'),
#  'education': ('10th grade',
#   '11th grade',
#   '12th grade no diploma',
#   '1st 2nd 3rd or 4th grade',
#   '5th or 6th grade',
#   '7th and 8th grade',
#   '9th grade',
#   'Associates degree-academic program',
#   'Associates degree-occup /vocational',
#   'Bachelors degree(BA AB BS)',
#   'Children',
#   'Doctorate degree(PhD EdD)',
#   'High school graduate',
#   'Less than 1st grade',
#   'Masters degree(MA MS MEng MEd MSW MBA)',
#   'Prof school degree (MD DDS DVM LLB JD)',
#   'Some college but no degree'),
#  'enroll_in_edu_inst_last_wk': ('College or university',
#   'High school',
#   'Not in universe'),
#  'marital_stat': ('Divorced',
#   'Married-A F spouse present',
#   'Married-civilian spouse present',
# ...

# %%
i0.categories0(df1)
# Out:
# {'class_of_worker': ('Federal government',
#   'Local government',
#   'Never worked',
#   'Not in universe',
#   'Private',
#   'Self-employed-incorporated',
#   'Self-employed-not incorporated',
#   'State government',
#   'Without pay'),
#  'education': ('10th grade',
#   '11th grade',
#   '12th grade no diploma',
#   '1st 2nd 3rd or 4th grade',
#   '5th or 6th grade',
#   '7th and 8th grade',
#   '9th grade',
#   'Associates degree-academic program',
#   'Associates degree-occup /vocational',
#   'Bachelors degree(BA AB BS)',
#   'Children',
#   'Doctorate degree(PhD EdD)',
#   'High school graduate',
#   'Less than 1st grade',
#   'Masters degree(MA MS MEng MEd MSW MBA)',
#   'Prof school degree (MD DDS DVM LLB JD)',
#   'Some college but no degree'),
#  'enroll_in_edu_inst_last_wk': ('College or university',
#   'High school',
#   'Not in universe'),
#  'marital_stat': ('Divorced',
#   'Married-A F spouse present',
#   'Married-civilian spouse present',
# ...

# %%
scaler = StandardScaler()

# %%
lb = LabelBinarizer()
lb.fit_transform(df1.income_binned.cat.codes)
# Out:
# 0         <=50k
# 1         <=50k
# 2         <=50k
# 3         <=50k
# 4         <=50k
# 5         <=50k
# 6         <=50k
# 7         <=50k
# 8         <=50k
# 9         <=50k
# 10        <=50k
# 11        <=50k
# 12        <=50k
# 13        <=50k
# 14        <=50k
# 15        <=50k
# 16        <=50k
# 17        <=50k
# 18        <=50k
# 19        <=50k
# 20        <=50k
# 21        <=50k
# 22        <=50k
# 23        <=50k
# 24        <=50k
# 25        <=50k
# 26        <=50k
# 27        <=50k
# 28        <=50k
# 29        <=50k
#           ...
# 299255    <=50k
# 299256    <=50k
# 299257    <=50k
# 299258    <=50k
# 299259    <=50k
# 299260    <=50k
# 299261    <=50k
# 299262    <=50k
# 299263    <=50k
# 299264    <=50k
# 299265    <=50k
# 299266    <=50k
# 299267    <=50k
# 299268    <=50k
# 299269    <=50k
# 299270    <=50k
# 299271    <=50k
# 299272    <=50k
# 299273    <=50k
# 299274    <=50k
# 299275    <=50k
# 299276    <=50k
# 299277    <=50k
# 299278    <=50k
# ...

# %%
df2 = df1.copy(deep=True)
df2 = i0.categories1(df2)
y = df2.income_binned.values
df2.drop(columns=['income_binned'], inplace=True)
X = df2.values
# Out:
# array([[73,  3,  0, ...,  2,  0, 95],
#        [58,  6,  4, ...,  2, 52, 94],
#        [18,  3,  0, ...,  2,  0, 95],
#        ...,
#        [24,  6,  1, ...,  2, 52, 94],
#        [30,  4, 45, ...,  2, 52, 95],
#        [67,  3,  0, ...,  2,  0, 94]], dtype=int64)

# %%
iris = datasets.load_iris()
iris.data.shape, iris.target.shape
X = iris.data
y = iris.target
# Out:
# ((150, 4), (150,))

# %%
clf = svm.SVC(kernel='linear', C=1)

# %%
scores = cross_val_score(clf, X, y, cv=5)
scores

# %%
clf =  MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(10, 10, 2), random_state=1, 
                     warm_start=True)
scores = cross_val_score(clf, X, y, cv=5)
scores

# %%
clf.fit(X, y)
# Out:
# MLPClassifier(activation='relu', alpha=1e-05, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(5, 5, 2), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=1, shuffle=True, solver='lbfgs', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=True)
